# %%
# import python libraries

import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt # visualizing data
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv(r'C:\Users\keshav\OneDrive\Desktop\Ceramic tableware.csv', encoding= 'unicode_escape')

# %%
df.shape
# Out:
# (15, 3)

# %%
df.head()
# Out:
#                                              Company  Volume      marks
# 0                              Silverstone Wholesale   56225  52.000000
# 1  Cedar Hospitality|Cedar Hospitality Supplies P...  141079  85.000000
# 2                                       Living India   74715  41.000000
# 3                                   Bunzl Anz Sydney   37611  48.333333
# 4                                   Elite Group Ltd.    3379  42.833333

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Company  15 non-null     object
#  1   Volume   15 non-null     int64
#  2   marks    15 non-null     float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 492.0+ bytes

# %%
df
# Out:
#                                               Company  Volume      marks
# 0                               Silverstone Wholesale   56225  52.000000
# 1   Cedar Hospitality|Cedar Hospitality Supplies P...  141079  85.000000
# 2                                        Living India   74715  41.000000
# 3                                    Bunzl Anz Sydney   37611  48.333333
# 4                                    Elite Group Ltd.    3379  42.833333
# 5                                         Living Indi   32622  37.333333
# 6                      Nautical N Tropical (Pty) Ltd.    4625  31.833333
# 7                                      Lavida Trading  134243  26.333333
# 8                                 Melfoods (Pty) Ltd.   78515  20.833333
# 9                                  Reward Hospitality  206602  15.333333
# 10                                Eluk / Inside India   16957   9.833333
# 11                                       Nemuki (Pty)   13134   4.333333
# ...

# %%
df.dropna()
# Out:
#                                               Company  Volume      marks
# 0                               Silverstone Wholesale   56225  52.000000
# 1   Cedar Hospitality|Cedar Hospitality Supplies P...  141079  85.000000
# 2                                        Living India   74715  41.000000
# 3                                    Bunzl Anz Sydney   37611  48.333333
# 4                                    Elite Group Ltd.    3379  42.833333
# 5                                         Living Indi   32622  37.333333
# 6                      Nautical N Tropical (Pty) Ltd.    4625  31.833333
# 7                                      Lavida Trading  134243  26.333333
# 8                                 Melfoods (Pty) Ltd.   78515  20.833333
# 9                                  Reward Hospitality  206602  15.333333
# 10                                Eluk / Inside India   16957   9.833333
# 11                                       Nemuki (Pty)   13134   4.333333
# ...

# %%
df['marks'] = df['marks'].astype('int')

# %%
df.dtypes
# Out:
# Company    object
# Volume      int64
# marks       int32
# dtype: object

# %%
df.columns
# Out:
# Index(['Company', 'Volume', 'marks'], dtype='object')

# %%
df.rename(columns= {'Company' : 'Companies'})
# Out:
#                                             Companies  Volume  marks
# 0                               Silverstone Wholesale   56225     52
# 1   Cedar Hospitality|Cedar Hospitality Supplies P...  141079     85
# 2                                        Living India   74715     41
# 3                                    Bunzl Anz Sydney   37611     48
# 4                                    Elite Group Ltd.    3379     42
# 5                                         Living Indi   32622     37
# 6                      Nautical N Tropical (Pty) Ltd.    4625     31
# 7                                      Lavida Trading  134243     26
# 8                                 Melfoods (Pty) Ltd.   78515     20
# 9                                  Reward Hospitality  206602     15
# 10                                Eluk / Inside India   16957      9
# 11                                       Nemuki (Pty)   13134      4
# 12                                    Bunzl Anz Sydne   24091     -1
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of                                               Company  Volume  marks
# 0                               Silverstone Wholesale   56225     52
# 1   Cedar Hospitality|Cedar Hospitality Supplies P...  141079     85
# 2                                        Living India   74715     41
# 3                                    Bunzl Anz Sydney   37611     48
# 4                                    Elite Group Ltd.    3379     42
# 5                                         Living Indi   32622     37
# 6                      Nautical N Tropical (Pty) Ltd.    4625     31
# 7                                      Lavida Trading  134243     26
# 8                                 Melfoods (Pty) Ltd.   78515     20
# 9                                  Reward Hospitality  206602     15
# 10                                Eluk / Inside India   16957      9
# 11                                       Nemuki (Pty)   13134      4
# ...

# %%
df.describe()
# Out:
#               Volume      marks
# count      15.000000  15.000000
# mean    56445.000000  30.533333
# std     60759.875456  24.616680
# min      2938.000000  -6.000000
# 25%     15045.500000  12.000000
# 50%     32622.000000  31.000000
# 75%     76615.000000  45.000000
# max    206602.000000  85.000000

# %%
df[['marks']].describe()
# Out:
#            marks
# count  15.000000
# mean   30.533333
# std    24.616680
# min    -6.000000
# 25%    12.000000
# 50%    31.000000
# 75%    45.000000
# max    85.000000

# %%
df = pd.read_csv(r'C:\Users\keshav\OneDrive\Desktop\Diwali Sales Data.csv', encoding= 'unicode_escape')

# %%
df.shape
# Out:
# (11251, 15)

# %%
df.head()
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
#
#             State      Zone       Occupation Product_Category  Orders  \
# 0     Maharashtra   Western       Healthcare             Auto       1
# 1  Andhra Pradesh  Southern             Govt             Auto       3
# 2   Uttar Pradesh   Central       Automobile             Auto       3
# 3       Karnataka  Southern     Construction             Auto       2
# 4         Gujarat   Western  Food Processing             Auto       2
#
#     Amount  Status  unnamed1
# 0  23952.0     NaN       NaN
# 1  23934.0     NaN       NaN
# ...

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount', 'Status', 'unnamed1'],
#       dtype='object')

# %%
ax = sns.countplot(x = 'Gender' data= df)
# Out:
#   Cell In[21], line 1
#     ax = sns.countplot(x = 'Gender' data= df)
#                            ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
ax = sns.countplot(x = 'Gender' data= df)
# Out:
#   Cell In[22], line 1
#     ax = sns.countplot(x = 'Gender' data= df)
#                            ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
sns.countplot(x = 'Gender' data= df)
# Out:
#   Cell In[23], line 1
#     sns.countplot(x = 'Gender' data= df)
#                       ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
sns.countplot(x = 'Gender',data= df)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
ax = sns.countplot(x = 'Gender', data = df)

for bars in ax.containers:
    ax.bar_label(bars)

# %%
df.groupby(['Gender'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)
# Out:
#   Gender       Amount
# 0      F  74335856.43
# 1      M  31913276.00

# %%
sales_gen = df.groupby(['Gender'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)

sns.barplot(x= 'Gender', y= 'Amount', data = sales_gen)
# Out:
# <Axes: xlabel='Gender', ylabel='Amount'>

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount', 'Status', 'unnamed1'],
#       dtype='object')

# %%
sns.countplot(data = df, x = 'Age Group', hue = 'Gender')
# Out:
# <Axes: xlabel='Age Group', ylabel='count'>

# %%
ax = sns.countplot(data=df, x = 'Age Group', hue = 'Gender')

for bars in ax.containers:
    ax.bar_label(bars)

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount', 'Status', 'unnamed1'],
#       dtype='object')

# %%
sns.countplot(data = df, x= 'State')
# Out:
# <Axes: xlabel='State', ylabel='count'>

# %%
df.groupby(['Gender'], as_index=False)['Orders'].sum().sort_values(by='Orders', ascending=False)
# Out:
#   Gender  Orders
# 0      F   19568
# 1      M    8439

# %%
sales_state = df.groupby(['Gender'], as_index=False)['Orders'].sum().sort_values(by='Orders', ascending=False)

sns.set(rc={'figure.figsize':(15,5)})

# %%
sales = df.groupby(['State'], as_index=False)['Orders'].sum().sort_values(by='Orders', ascending=False).head(10)

sns.set(rc={'figure.figsize':(15,7)})

sns.barplot(x= 'State', y= 'Orders', data = sales)
# Out:
# <Axes: xlabel='State', ylabel='Orders'>

# %%
sales = df.groupby(['State'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False).head(10)

sns.set(rc={'figure.figsize':(15,7)})

sns.barplot(x= 'State', y= 'Amount', data = sales)
# Out:
# <Axes: xlabel='State', ylabel='Amount'>

# %%
sns.countplot(data = df, x= 'Marital_Status')
# Out:
# <Axes: xlabel='Marital_Status', ylabel='count'>

# %%
ax = sns.countplot(data = df, x= 'Marital_Status')
for bar in ax.containers:
    ax.bar_label(bars)

# %%
ax = sns.countplot(data = df, x= 'Marital_Status', hue = 'Gender')
sns.set(rc={'figure.figsize':(5,5)})

for bars in ax.containers:
    ax.bar_label(bars)

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount', 'Status', 'unnamed1'],
#       dtype='object')

# %%
sns.countplot(data = df, x = 'Occupation').head(10)

sns.set(rc={'figure.figsize':(15,5)})
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[70], line 1
# ----> 1 sns.countplot(data = df, x = 'Occupation').head(10)
#       3 sns.set(rc={'figure.figsize':(15,5)})
#
# AttributeError: 'Axes' object has no attribute 'head'

# %%
ax = sns.countplot(data = df , x = 'Occupation')
sns.set(rc={'figure.figsize':(17,7)})
for bars in ax.containers:
    ax.bar_label(bars)

# %%
sales = df.groupby(['Occupation'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False).head(10)

sns.set(rc={'figure.figsize':(15,7)})

sns.barplot(x= 'Occupation', y= 'Amount', data = sales)
# Out:
# <Axes: xlabel='Occupation', ylabel='Amount'>

# %%
pd.columns
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[78], line 1
# ----> 1 pd.columns
#
# AttributeError: module 'pandas' has no attribute 'columns'

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount', 'Status', 'unnamed1'],
#       dtype='object')

# %%
ax = sns.countplot(data = df, x = 'Product_Category')
sns.set(rc={'figure.figsize':(20,5)})
for bars in ax.containers:
    ax.bar_label(bars)

# %%
prd_sales = df.groupby(['Product_Category'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False).head(10)

sns.set(rc={'figure.figsize':(15,7)})

sns.barplot(x= 'Product_Category', y= 'Amount', data = prd_sales)
# Out:
# <Axes: xlabel='Product_Category', ylabel='Amount'>
